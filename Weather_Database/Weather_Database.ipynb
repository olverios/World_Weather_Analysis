# %%
from citipy import citipy

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-1000, high=1000, size=2000)
lngs = np.random.uniform(low=-1000, high=1000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 47

# %%
# Perform an API call with the OpenWeatherMap.
import time
from datetime import datetime
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Retrieve the following information from the API call:
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | leningradskiy
# Processing Record 2 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | asau
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | beringovskiy
# Processing Record 8 of Set 1 | tolaga bay
# Processing Record 9 of Set 1 | longyearbyen
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | dunedin
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | saskylakh
# Processing Record 19 of Set 1 | waipawa
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | kahului
# Processing Record 22 of Set 1 | pevek
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 1 | dikson
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | egvekinot
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | narsaq
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | upernavik
# Processing Record 46 of Set 1 | meulaboh
# Processing Record 47 of Set 1 | mezen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Leningradskiy  69.3833  178.4167     29.08        84         100
# 1        Ushuaia -54.8000  -68.3000     47.86        43           0
# 2           Asau  46.4333   26.4000     42.28        81          21
# 3          Vaini -21.2000 -175.2000     78.96        78          40
# 4   Puerto Ayora  -0.7393  -90.3518     71.55        93          28
# 5   Beringovskiy  63.0500  179.3167     34.12        96         100
# 6     Tolaga Bay -38.3667  178.3000     65.17        59          49
# 7   Longyearbyen  78.2186   15.6401     12.04        57          20
# 8          Bluff -46.6000  168.3333     58.80        92         100
# 9         Barrow  71.2906 -156.7887     24.82        86         100
#
#    Wind Speed Country                 Date
# 0        6.15      RU  2022-05-08 02:26:05
# 1       16.11      AR  2022-05-08 02:26:07
# 2        2.30      RO  2022-05-08 02:26:08
# 3        9.22      TO  2022-05-08 02:26:09
# 4        7.20      EC  2022-05-08 02:22:14
# 5        6.15      RU  2022-05-08 02:26:11
# 6        7.52      NZ  2022-05-08 02:26:12
# 7       11.50      SJ  2022-05-08 02:26:13
# 8        5.26      NZ  2022-05-08 02:26:14
# 9        8.05      US  2022-05-08 02:26:15

# %%
# Export the DataFrame as a CSV file,
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
